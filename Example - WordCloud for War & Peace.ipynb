# %%
# !pip install wordcloud
# !pip install fileupload
# !pip install ipywidgets
# !jupyter nbextension install --py --user fileupload
# !jupyter nbextension enable --py fileupload

import wordcloud
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display
import fileupload
import io
import sys

# %%
# War & Peace by Tolstoy
# https://www.gutenberg.org/ebooks/2600

# %%
file = '../../Github/python-data-science/data/book_war_and_peace.txt'

# %%
# Read file
with open(file, 'r', encoding="utf8") as f:
    file_contents = f.read()
f.close()

# %%
type(file_contents)
# Out:
# str

# %%
def calculate_frequencies(file_contents):
    # Here is a list of punctuations and uninteresting words you can use to process your text
    punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    uninteresting_words = ["the", "a", "to", "if", "is", "it", "of", "and", "or", "an", "as", "i", "me", "my", \
    "we", "our", "ours", "you", "your", "yours", "he", "she", "him", "his", "her", "hers", "its", "they", "them", \
    "their", "what", "which", "who", "whom", "this", "that", "am", "are", "was", "were", "be", "been", "being", \
    "have", "has", "had", "do", "does", "did", "but", "at", "by", "with", "from", "here", "when", "where", "how", \
    "all", "any", "both", "each", "few", "more", "some", "such", "no", "nor", "too", "very", "can", "will", "just", \
    "on", "so", "not", "in", "for", "one", "said", "only", "those","could", "would"]
    
    # LEARNER CODE START HERE
    book = {}
    for word in file_contents.split():
        clean_word = str()
        if len(word) > 1:
            for letter in word:
                if letter in punctuations:
                    pass
                elif letter.isalpha():
                    clean_word +=letter

            clean_word = clean_word.lower()
            
            if clean_word not in uninteresting_words:
                if clean_word in book.keys():
                    book[clean_word] = book[clean_word] + 1
                else:
                    book[clean_word] = 1

            
    
    #wordcloud
    cloud = wordcloud.WordCloud()
    cloud.generate_from_frequencies(book)
    return cloud.to_array()

# %%
myimage = calculate_frequencies(file_contents)

# %%
plt.figure(figsize=(10,8))
plt.imshow(myimage, interpolation = 'nearest')
plt.axis('off')
plt.show()
